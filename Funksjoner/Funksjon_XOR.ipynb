# %% [markdown]
# <a href="https://colab.research.google.com/github/perarneskjelvik/Selvstudium/blob/main/Funksjon_XOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Funksjon XOR
#
# Forfatter: Per Arne Skjelvik
#
# Dato: 19.2.2026
#
# ##Formål
# Programmet bruker nevrale nettverk for å lære XOR-funksjonen.

# %%
# importerer nødvendige bibliotek

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.metrics import Recall, Precision, AUC
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, TensorBoard, EarlyStopping
import random
import matplotlib.pyplot as plt

# %%
# Treningsdata XOR-funksjon
x = []
y = []

x = [[0,0],[0,1],[1,0],[1,1]]
y = [0,1,1,0]

# %%
# Setter seed for random.
# Får da samme beregning av vekter hver gang vi kjører koden.

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)


# Definerer lagene/strukturen i modellen

# Nettverket er sekvensielt, dvs hvert lag sender output direkte til neste lag.
model = tf.keras.models.Sequential()

# Definerer input layer som har 2 input
model.add(tf.keras.Input(shape=(2,)))

# Legger til et ekstra skjult lag
model.add(tf.keras.layers.Dense(units=8, activation='sigmoid'))

# Definerer output layer som har kun 1 node/output
# Bruker sigmoid som aktiveringsfunksjon (s-kurve, output alltid mellom 0 og 1)
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

print("Oppsummering modell:")
print("")
print(model.summary())
print("")
input("Trykk enter for å fortsette:")

# Plotter modellen til en *.jpg fil
plot_model(model, to_file='plottfil.jpg', show_shapes=True)

# Kompilerer modellen

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.3),
              loss=keras.losses.MeanSquaredError(),
              metrics=['accuracy', Recall(name='recall'),
                       Precision(name='precision'), AUC(name='auc')])


# Trener modellen
model.fit(np.array(x), np.array(y), batch_size=4, epochs=500)

# %%
# Tester modellen
print("Tester modellen:")
q = model.predict( np.array( [[0,0],[0,1],[1,0],[1,1] ] )  )
print(q)

# Fasit
print("Fasit:")
print("0")
print("1")
print("1")
print("0")
# Out:
# Tester modellen:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# [[0.00103646]
#  [0.9916089 ]
#  [0.9951998 ]
#  [0.01332764]]
# Fasit:
# 0
# 1
# 1
# 0
